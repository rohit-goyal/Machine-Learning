# %% [markdown]
# # **Importing Libraries**

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %% [markdown]
# Problem Statement
#
# *You have been given a Dataset that describes the functionality of houses.
# Now, based on the given features you have to predict the house price

# %% [markdown]
# # **Defining The Data Frame**

# %%
df = pd.read_csv('/content/Housing.csv')

# %% [markdown]
# ## **EDA**

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %%
df.shape[0] #For Rows
# Out:
# 545

# %%
df.shape[1] #For Columns
# Out:
# 13

# %%
len(df.columns)
# Out:
# 13

# %%
df.columns #Print All the Columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.nunique()
# Out:
# price               219
# area                284
# bedrooms              6
# bathrooms             4
# stories               4
# mainroad              2
# guestroom             2
# basement              2
# hotwaterheating       2
# airconditioning       2
# parking               4
# prefarea              2
# furnishingstatus      3
# dtype: int64

# %%
df.isnull().sum() # Find number of null values in each columns
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.isnull().sum().sum() #Find Total Numeber of null values in Entire Dataset
# Out:
# 0

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.mainroad.unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df.mainroad.value_counts()
# Out:
# yes    468
# no      77
# Name: mainroad, dtype: int64

# %%
newdf = df.copy()

# %%
newdf.mainroad.replace(['yes','no'],[1,0])
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 540    1
# 541    0
# 542    1
# 543    0
# 544    1
# Name: mainroad, Length: 545, dtype: int64

# %%
newdf.mainroad.replace(['yes','no'],[1,0]).value_counts()
# Out:
# 1    468
# 0     77
# Name: mainroad, dtype: int64

# %%
newdf.mainroad.replace(['yes','no'],[1,0] ,inplace=True)

# %%
df.mainroad.replace(['yes','no'],[1,0] ,inplace=True)

# %%
newdf.mainroad.dtypes
# Out:
# dtype('int64')

# %%
newdf.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 1
# 1                 1
# 2                 2
# 3                 1
# 4                 1

# %%
df.guestroom.value_counts()
# Out:
# no     448
# yes     97
# Name: guestroom, dtype: int64

# %%
df.guestroom.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df.guestroom.replace(['yes','no'],[1,0] ,inplace=True) #guestroom

# %%
df.basement.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df.basement.value_counts()
# Out:
# no     354
# yes    191
# Name: basement, dtype: int64

# %%
df.basement.replace(['yes','no'],[1,0] ,inplace=True) #basement

# %%
df.hotwaterheating.replace(['yes','no'],[1,0] ,inplace=True) #hotwaterheating

# %%
df.airconditioning.replace(['yes','no'],[1,0] ,inplace=True) #airconditioning

# %%
df.prefarea.replace(['yes','no'],[1,0] ,inplace=True) #prefarea

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %%
df.furnishingstatus.unique()
# Out:
# array(['furnished', 'semi-furnished', 'unfurnished'], dtype=object)

# %%
df.furnishingstatus.value_counts()
# Out:
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: furnishingstatus, dtype: int64

# %%
df.furnishingstatus.replace(['furnished','unfurnished','semi-furnished'],[1,0,2] ,inplace=True) #furnishingstatus

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 1
# 1                 1
# 2                 2
# 3                 1
# 4                 1

# %% [markdown]
# **Observations**
#
# Data Strength = 545
#
#
# Number of Random Variables = 13
#
# None of the column contains Null Values
#
# Columns = price,bedrooms,bathrooms,area,stories,parking  has numerical value
#
# columns = mainroad,guestroom,basement,hotwaterheating,airconditioning ,prefarea,furnishingstatus has object values

# %% [markdown]
# #**Manipulation**
#
#
#     Changed the categorical values to numerical values for the columns(mainroad,guestroom,basement,hotwaterheating,airconditioning ,prefarea,furnishingstatus)

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#          mainroad   guestroom    basement  hotwaterheating  airconditioning  \
# count  545.000000  545.000000  545.000000       545.000000       545.000000
# mean     0.858716    0.177982    0.350459         0.045872         0.315596
# std      0.348635    0.382849    0.477552         0.209399         0.465180
# ...

# %%
newdf.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#          mainroad   guestroom    basement  hotwaterheating  airconditioning  \
# count  545.000000  545.000000  545.000000       545.000000       545.000000
# mean     0.858716    0.177982    0.350459         0.045872         0.315596
# std      0.348635    0.382849    0.477552         0.209399         0.465180
# ...

# %%
df.corr()
# Out:
#                      price      area  bedrooms  bathrooms   stories  mainroad  \
# price             1.000000  0.535997  0.366494   0.517545  0.420712  0.296898
# area              0.535997  1.000000  0.151858   0.193820  0.083996  0.288874
# bedrooms          0.366494  0.151858  1.000000   0.373930  0.408564 -0.012033
# bathrooms         0.517545  0.193820  0.373930   1.000000  0.326165  0.042398
# stories           0.420712  0.083996  0.408564   0.326165  1.000000  0.121706
# mainroad          0.296898  0.288874 -0.012033   0.042398  0.121706  1.000000
# guestroom         0.255517  0.140297  0.080549   0.126469  0.043538  0.092337
# basement          0.187057  0.047417  0.097312   0.102106 -0.172394  0.044002
# hotwaterheating   0.093073 -0.009229  0.046049   0.067159  0.018847 -0.011781
# airconditioning   0.452954  0.222393  0.160603   0.186915  0.293602  0.105423
# parking           0.384394  0.352980  0.139270   0.177496  0.045547  0.204433
# ...

# %%
newdf.corr()
# Out:
#                      price      area  bedrooms  bathrooms   stories  mainroad  \
# price             1.000000  0.535997  0.366494   0.517545  0.420712  0.296898
# area              0.535997  1.000000  0.151858   0.193820  0.083996  0.288874
# bedrooms          0.366494  0.151858  1.000000   0.373930  0.408564 -0.012033
# bathrooms         0.517545  0.193820  0.373930   1.000000  0.326165  0.042398
# stories           0.420712  0.083996  0.408564   0.326165  1.000000  0.121706
# mainroad          0.296898  0.288874 -0.012033   0.042398  0.121706  1.000000
# guestroom         0.255517  0.140297  0.080549   0.126469  0.043538  0.092337
# basement          0.187057  0.047417  0.097312   0.102106 -0.172394  0.044002
# hotwaterheating   0.093073 -0.009229  0.046049   0.067159  0.018847 -0.011781
# airconditioning   0.452954  0.222393  0.160603   0.186915  0.293602  0.105423
# parking           0.384394  0.352980  0.139270   0.177496  0.045547  0.204433
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True, cmap='Reds')

# %%
plt.figure(figsize=(10,10))
sns.heatmap(newdf.corr(), annot=True, cmap='Reds')

# %%
plt.scatter(df.area , df.price)

# %%
plt.scatter(newdf.area , newdf.price)

# %%
sns.pairplot(df)

# %%
sns.pairplot(newdf)

# %%
plt.figure(figsize=(50,50))
df.boxplot()

# %%
df[['area']].boxplot()

# %%
plt.figure(figsize=(50,50))
newdf.boxplot()

# %%
df[['price']].boxplot()

# %%
df[['bedrooms']].boxplot()

# %%
df.bedrooms.loc[df.bedrooms > 4].sum() # How many values are there where bedrooms is more than 4
# Out:
# 62

# %%
count = 0
for i in df['bedrooms']:
  if i > 4:
    count+=1
print(count)
# Out:
# 12

# %%
df.bedrooms.loc[df.bedrooms > 4]
# Out:
# 7      5
# 28     5
# 34     5
# 89     5
# 112    6
# 143    5
# 152    5
# 271    5
# 340    5
# 356    5
# 395    6
# 536    5
# Name: bedrooms, dtype: int64

# %%
len(df.bedrooms.loc[df.bedrooms > 4])
# Out:
# 12

# %%
df.shape
# Out:
# (545, 13)

# %%
df[['mainroad']].boxplot()

# %%
len(df.mainroad.loc[newdf.mainroad == 0])
# Out:
# 77

# %%
sns.histplot(df.price)

# %%
sns.histplot(df.mainroad)

# %%
df.basement.value_counts().plot.bar()

# %%
df.mainroad.value_counts().plot.bar()

# %%
df.price.value_counts().plot.bar()

# %%
df.area.value_counts().plot.bar()

# %%
df.loc[df.bedrooms == 4,['price','bedrooms','bathrooms']][df.bathrooms ==2] # what is the price of house where bedrooms is 4 and bathrooms is 2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         price  bedrooms  bathrooms
# 0    13300000         4          2
# 3    12215000         4          2
# 12    9310000         4          2
# 13    9240000         4          2
# 16    9100000         4          2
# 25    8540000         4          2
# 29    8400000         4          2
# 32    8295000         4          2
# 37    7980000         4          2
# 39    7910000         4          2
# 43    7700000         4          2
# 44    7560000         4          2
# 52    7350000         4          2
# 57    7245000         4          2
# 58    7210000         4          2
# 62    7070000         4          2
# 63    7035000         4          2
# 69    6790000         4          2
# 71    6755000         4          2
# 75    6650000         4          2
# ...

# %% [markdown]
# #Splitting The Dataset

# %%
df.head(2)
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
#
#    furnishingstatus
# 0                 1
# 1                 1

# %%
df[df.columns[1:]] #df.drop('price' , axis=1)
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          0         0
# 1    8960         4          4        4         1          0         0
# 2    9960         3          2        2         1          0         1
# 3    7500         4          2        2         1          0         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          0         1
# 541  2400         3          1        1         0          0         0
# 542  3620         2          1        1         1          0         0
# 543  2910         3          1        1         0          0         0
# 544  3850         3          1        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# ...

# %%
df['price']
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
df.price
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
df.price.ndim
# Out:
# 1

# %%
df.drop('price' , axis=1).ndim
# Out:
# 2

# %%
x = df.drop('price' , axis=1)
y = df.price

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
len(x_train )
# Out:
# 436

# %%
len(x_test)
# Out:
# 109

# %%
len(y_train)
# Out:
# 436

# %%
len(y_test)
# Out:
# 109

# %% [markdown]
# # Choosing The Model

# %%
model = LinearRegression()

# %% [markdown]
# # Train The Model

# %%
model.fit(x_train ,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_ #Intercept the value
# Out:
# -153020.39767693914

# %%
model.coef_ #coefficient the value
# Out:
# array([2.37359519e+02, 7.42382082e+04, 1.09878563e+06, 4.22818367e+05,
#        3.99602240e+05, 2.36368961e+05, 4.13764911e+05, 6.96228583e+05,
#        8.14587673e+05, 2.37846833e+05, 6.34405791e+05, 1.26914419e+05])

# %% [markdown]
# # Prediction

# %%
y_test
# Out:
# 316    4060000
# 77     6650000
# 360    3710000
# 90     6440000
# 493    2800000
#         ...
# 15     9100000
# 357    3773000
# 39     7910000
# 54     7350000
# 155    5530000
# Name: price, Length: 109, dtype: int64

# %%
pred_y = model.predict(x_test)

# %%
pred_y
# Out:
# array([5239173.32762718, 7054067.57583383, 3129423.54574214,
#        4668932.93211896, 3057758.57376511, 3585956.42796038,
#        5430399.31975463, 6182620.74176088, 2760320.64728725,
#        2359083.3399644 , 9746225.66150697, 2850434.59951216,
#        3214625.09528042, 3417524.84438337, 3769801.02852143,
#        5309671.85335955, 3068028.49401721, 4890310.44714619,
#        4453883.75758458, 3594648.20323524, 5899893.81059038,
#        5963835.34944124, 2782787.13656036, 4838071.49471231,
#        5330250.73959906, 7654298.46783181, 3300237.03688317,
#        5001631.29984533, 8012230.93813927, 3178473.5945452 ,
#        6578529.7401813 , 3392127.35949438, 6537350.98622346,
#        4237680.88295261, 3621348.73870717, 5910621.58319738,
#        4896147.52750411, 4471112.88912377, 3231897.01884388,
#        4375178.05890928, 4614551.92546614, 3592864.97825681,
#        7035078.81430349, 3775390.05875499, 3772667.84258209,
# ...

# %%
newdf = pd.DataFrame({"Actual Value":y_test , "Predicted value":pred_y})

# %%
newdf
# Out:
#      Actual Value  Predicted value
# 316       4060000     5.239173e+06
# 77        6650000     7.054068e+06
# 360       3710000     3.129424e+06
# 90        6440000     4.668933e+06
# 493       2800000     3.057759e+06
# ..            ...              ...
# 15        9100000     5.055402e+06
# 357       3773000     4.098018e+06
# 39        7910000     7.162800e+06
# 54        7350000     6.479294e+06
# 155       5530000     6.188358e+06
#
# [109 rows x 2 columns]

# %%
plt.scatter(newdf['Actual Value'],newdf['Predicted value'])
plt.xlabel('Actual value')
plt.ylabel('Predicted value')
plt.title('Actual Value v/s Predicted Value')
# Out:
# Text(0.5, 1.0, 'Actual Value v/s Predicted Value')

# %%
newdf.corr()
# Out:
#                  Actual Value  Predicted value
# Actual Value         1.000000         0.822513
# Predicted value      0.822513         1.000000

# %%
sns.heatmap(newdf.corr() , annot=True , cmap='magma')

# %%
x_test
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 316  5900         4          2        2         0          0         1
# 77   6500         3          2        3         1          0         0
# 360  4040         2          1        1         1          0         0
# 90   5000         3          1        2         1          0         0
# 493  3960         3          1        1         1          0         0
# ..    ...       ...        ...      ...       ...        ...       ...
# 15   6000         4          1        2         1          0         1
# 357  6930         4          1        2         0          0         0
# 39   6000         4          2        4         1          0         0
# 54   6000         3          2        2         1          1         0
# 155  6100         3          2        1         1          0         1
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# ...

# %%
x_test.area
# Out:
# 316    5900
# 77     6500
# 360    4040
# 90     5000
# 493    3960
#        ...
# 15     6000
# 357    6930
# 39     6000
# 54     6000
# 155    6100
# Name: area, Length: 109, dtype: int64

# %%
#Simple Linear Regression
plt.scatter(x_test.area,y_test)
plt.plot(x_test.area,pred_y,color='green')

# %%
a = int(input("Enter the area:"))

# %% [markdown]
# # Testing The Model

# %%
r2_score(y_test,pred_y)
# Out:
# 0.6542221839581839
